# %% [markdown]
# # The CIFAR-10 dataset
#
# https://www.cs.toronto.edu/~kriz/cifar.html
#
# The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.
#
# The dataset is divided into five training batches and one test batch, each with 10000 images. The test batch contains exactly 1000 randomly-selected images from each class. The training batches contain the remaining images in random order, but some training batches may contain more images from one class than another. Between them, the training batches contain exactly 5000 images from each class.
#
# Here are the classes in the dataset, as well as 10 random images from each:
#
# ![36.png](data:image/png;base64,...)

# %% [markdown]
# ## Download the raw data files

# %%
# Download CIFAR-10 dataset at https://www.cs.toronto.edu/~kriz/cifar.html
import urllib.request
urllib.request.urlretrieve("https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz", "cifar-10-python.tar.gz")

# !tar -xzvf '/content/cifar-10-python.tar.gz'
# Out:
# cifar-10-batches-py/
# cifar-10-batches-py/data_batch_4
# cifar-10-batches-py/readme.html
# cifar-10-batches-py/test_batch
# cifar-10-batches-py/data_batch_3
# cifar-10-batches-py/batches.meta
# cifar-10-batches-py/data_batch_2
# cifar-10-batches-py/data_batch_5
# cifar-10-batches-py/data_batch_1

# %% [markdown]
# ## "cifar-10-batches-py"
# Inside the unzipped folder "cifar-10-batches-py", there are
# * 5 training data batch files: 'data_batch_1', 'data_batch_2', to 'data_batch_5',
# * 1 testting data batch file 'test_batch',
# * 1 file 'batch.meta', and
# * 1 file 'readme.html'
#
# Each of these batch files is a Python "pickled" object produced with cPickle.
#
# Each of the data batch files contains a dictionary with the following elements:
# * data -- a 10000x3072 numpy array of uint8s. Each row of the array stores a 32x32 colour image. The first 1024 entries contain the red channel values, the next 1024 the green, and the final 1024 the blue. The image is stored in row-major order, so that the first 32 entries of the array are the red channel values of the first row of the image.
# * labels -- a list of 10000 numbers in the range 0-9. The number at index i indicates the label of the ith image in the array data.

# %%
# Here is a method to to open the pickled file
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='latin1')
    return dict

# for example
filepath = '/content/cifar-10-batches-py/data_batch_1'
data_batch_1 = unpickle(filepath)

print(type(data_batch_1))
print()

print(data_batch_1.keys())
print()

batch_1_dataItems = data_batch_1['data']
batch_1_labelItems = data_batch_1['labels']

print(type(batch_1_dataItems))
print(batch_1_dataItems.shape)
print()

print(type(batch_1_labelItems))
print(len(batch_1_dataItems))
print()
# Out:
# <class 'dict'>
#
# dict_keys(['batch_label', 'labels', 'data', 'filenames'])
#
# <class 'numpy.ndarray'>
# (10000, 3072)
#
# <class 'list'>
# 10000

# %%
# class names
class_names = ['airplane','automobile','bird','cat','deer', 'dog','frog','horse','ship','truck']

import matplotlib.pyplot as plt
# %matplotlib inline

idx = 0

img = data_batch_1['data'][idx].reshape(3, 32, 32).transpose(1,2,0).astype("uint8")

plt.imshow(img)
plt.title(class_names[data_batch_1['labels'][idx]])
plt.show()
print()

# %% [markdown]
# # Build a Custom Dataset
#
# https://pytorch.org/docs/stable/data.html
#
# PyTorch supports two different types of datasets:
# * **map-style datasets**: a map-style dataset is one that implements the \_\_getitem\_\_() and \_\_len\_\_() protocols, and represents a map from (possibly non-integral) indices/keys to data samples.
# * **iterable-style datasets**: an iterable-style dataset is an instance of a subclass of IterableDataset that implements the \_\_iter\_\_() protocol, and represents an iterable over data samples.
#
#
#
# ---
#
#
#
#
# https://pytorch.org/tutorials/beginner/basics/data_tutorial.html
#
# A custom Dataset class must implement three functions:
# * **\_\_init\_\_()**: this function is run once when instantiating the Dataset object
# * **\_\_getitem\_\_()**: this function loads and returns a sample from the dataset at the given index idx. Based on the index, it identifies the image’s location on disk, retrieves the corresponding label, calls the transform functions on them (if applicable), and returns the tensor image and corresponding label in a tuple.
# * **\_\_len\_\_()**: this function returns the number of samples in our dataset.
#
#
# ---
#
# **Below presents a simplied implementation of a CustomDataset for CIFAR10.** The complete implementation can be found at https://pytorch.org/vision/stable/_modules/torchvision/datasets/cifar.html
#
#
# Note that
# * The **Dataset** retrieves our dataset’s features and labels one sample at a time.
# * We have loaded that dataset into the **DataLoader** and can iterate through the dataset as needed.
# >- While training a model, we typically want to pass samples in “minibatches”, reshuffle the data at every epoch to reduce model overfitting, and use Python’s multiprocessing to speed up data retrieval.

# %%
import os
import pickle
import numpy as np
from PIL import Image
from torch.utils.data import Dataset

class CustomDatasetCIFAR10(Dataset):
  base_folder = "cifar-10-batches-py"
  train_list = ["data_batch_1","data_batch_2","data_batch_3","data_batch_4","data_batch_5"]
  test_list = ["test_batch"]

  def __init__(self, root, train = True, transform = None, target_transform = None):
    super().__init__()
    self.root = root
    self.train = train
    self.transform = transform
    self.target_transform = target_transform

    if self.train:
      downloaded_list = self.train_list
    else:
      downloaded_list = self.test_list
    self.data = []
    self.targets = []

    for file_name in downloaded_list:
      file_path = os.path.join(self.root, self.base_folder, file_name)
      with open(file_path, 'rb') as fo:
        dict = pickle.load(fo, encoding='latin1')
        self.data.append(dict['data'])
        self.targets.extend(dict['labels'])
    self.data = np.vstack(self.data).reshape(-1, 3, 32, 32)
    self.data = self.data.transpose((0, 2, 3, 1))  # convert to Hight by Width by Channel

  def __getitem__(self, idx):
    img, target = self.data[idx], self.targets[idx]
    img = Image.fromarray(img)  # doing this so that it is consistent with all other datasets to return a PIL Image
    if self.transform is not None:
      img = self.transform(img)
    if self.target_transform is not None:
      target = self.target_transform(target)
    return img, target

  def __len__(self):
    return len(self.data)

# %%
data_path = "./"

cifar10 = CustomDatasetCIFAR10(data_path, train=True)

# %% [markdown]
# # Test the Dataset

# %%
# class names
class_names = ['airplane','automobile','bird','cat','deer', 'dog','frog','horse','ship','truck']

# visualize by showing some images from the dataset
fig = plt.figure(figsize=(8,3))
num_classes = 10
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    ax.set_title(class_names[i])
    img = next(img for img, label in cifar10 if label == i)   #Here, we get a PIL (Python Imaging Library, the PIL package) image
    plt.imshow(img)
plt.show()

# %% [markdown]
# # Prepare Dataset objects

# %%
from torchvision import transforms

data_path = './'

cifar10 = CustomDatasetCIFAR10(data_path, train=True,
    transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4915, 0.4823, 0.4468),
                             (0.2470, 0.2435, 0.2616))
    ]))

cifar10_val = CustomDatasetCIFAR10(data_path, train=False,
    transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4915, 0.4823, 0.4468),
                             (0.2470, 0.2435, 0.2616))
    ]))

n_out = 10

# %% [markdown]
# # Prepare Dataloader objects

# %%
import torch

kwargs = {'num_workers': 1, 'pin_memory': True} if torch.cuda.is_available()else {}

train_loader = torch.utils.data.DataLoader(cifar10, batch_size=64, shuffle=True,  **kwargs)

val_loader = torch.utils.data.DataLoader(cifar10_val, batch_size=64,shuffle=False, **kwargs)

# %% [markdown]
# # Previous Example of Image Classification

# %%
import torch.nn as nn
import torch.optim as optim

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

model = nn.Sequential(
    nn.Linear(3072, 1024),
    nn.Tanh(),
    nn.Linear(1024, 512),
    nn.Tanh(),
    nn.Linear(512, 128),
    nn.Tanh(),
    nn.Linear(128, n_out)
)

model.to(device)  # move model parameters to GPU for computation acceleration

learning_rate = 1e-2

optimizer = optim.SGD(model.parameters(), lr=learning_rate)

loss_fn = nn.CrossEntropyLoss()

n_epochs = 100

for epoch in range(n_epochs):
    model.train(True)
    for imgs, labels in train_loader:
        imgs, labels = imgs.to(device), labels.to(device)   # move tensors to GPU for computation acceleration

        # imgs.view(imgs.shape[0], -1): In order to call the model, we need to make the input have the right dimensions.
        # We recall that our model expects 3,072 features in the input, and that nn works with data organized into batches along the zeroth dimension.
        # So we need to turn our 3 × 32 × 32 image into a 1D tensor and then add an extra dimension in the zeroth position.
        outputs = model(imgs.view(imgs.shape[0], -1))
        train_loss = loss_fn(outputs, labels)

        optimizer.zero_grad()
        train_loss.backward()
        optimizer.step()

    model.eval()

    correct = 0
    total = 0
    with torch.no_grad():
        for imgs, labels in val_loader:
            imgs, labels = imgs.to(device), labels.to(device)   # move tensors to GPU for computation acceleration

            outputs = model(imgs.view(imgs.shape[0], -1))
            val_loss = loss_fn(outputs, labels)

            _, predicted = torch.max(outputs, dim=1)
            total += labels.shape[0]
            correct += int((predicted == labels).sum())
    print("Epoch: %d, train_loss: %f, val_loss: %f, val_accuracy: %f" % (epoch, float(train_loss), float(val_loss), (correct / total)))
# Out:
# cuda:0
# Epoch: 0, train_loss: 1.809896, val_loss: 1.657668, val_accuracy: 0.375700
# Epoch: 1, train_loss: 1.950519, val_loss: 1.663338, val_accuracy: 0.401000
# Epoch: 2, train_loss: 1.307453, val_loss: 1.649653, val_accuracy: 0.408000
# Epoch: 3, train_loss: 1.630224, val_loss: 1.720202, val_accuracy: 0.406300
# Epoch: 4, train_loss: 1.560901, val_loss: 1.590092, val_accuracy: 0.432700
# Epoch: 5, train_loss: 1.500485, val_loss: 1.540168, val_accuracy: 0.446500
# Epoch: 6, train_loss: 1.397909, val_loss: 1.670024, val_accuracy: 0.449600
# Epoch: 7, train_loss: 1.381764, val_loss: 1.577661, val_accuracy: 0.456000
# Epoch: 8, train_loss: 1.460285, val_loss: 1.780827, val_accuracy: 0.442500
# Epoch: 9, train_loss: 1.051090, val_loss: 1.482261, val_accuracy: 0.444600
# Epoch: 10, train_loss: 1.183201, val_loss: 1.564486, val_accuracy: 0.467700
# Epoch: 11, train_loss: 1.068709, val_loss: 1.595804, val_accuracy: 0.470000
# Epoch: 12, train_loss: 1.252167, val_loss: 1.739864, val_accuracy: 0.433900
# Epoch: 13, train_loss: 1.260113, val_loss: 1.736493, val_accuracy: 0.476800
# Epoch: 14, train_loss: 1.495778, val_loss: 1.784405, val_accuracy: 0.470500
# Epoch: 15, train_loss: 0.929636, val_loss: 1.764317, val_accuracy: 0.484500
# Epoch: 16, train_loss: 0.755574, val_loss: 1.904236, val_accuracy: 0.466300
# Epoch: 17, train_loss: 1.208186, val_loss: 1.978751, val_accuracy: 0.467500
# Epoch: 18, train_loss: 0.835371, val_loss: 2.086118, val_accuracy: 0.469800
# Epoch: 19, train_loss: 1.141793, val_loss: 2.577137, val_accuracy: 0.413200
# Epoch: 20, train_loss: 0.942091, val_loss: 2.416153, val_accuracy: 0.424000
# Epoch: 21, train_loss: 0.690052, val_loss: 1.723697, val_accuracy: 0.470400
# Epoch: 22, train_loss: 0.581143, val_loss: 2.033544, val_accuracy: 0.472600
# Epoch: 23, train_loss: 0.657202, val_loss: 2.004428, val_accuracy: 0.486200
# Epoch: 24, train_loss: 0.708491, val_loss: 1.957813, val_accuracy: 0.471400
# Epoch: 25, train_loss: 0.522521, val_loss: 2.082617, val_accuracy: 0.466100
# Epoch: 26, train_loss: 0.692944, val_loss: 2.275688, val_accuracy: 0.442100
# Epoch: 27, train_loss: 0.779503, val_loss: 2.185802, val_accuracy: 0.437600
# Epoch: 28, train_loss: 1.055819, val_loss: 2.501880, val_accuracy: 0.420600
# Epoch: 29, train_loss: 1.079646, val_loss: 3.562181, val_accuracy: 0.352700
# Epoch: 30, train_loss: 0.397842, val_loss: 2.371021, val_accuracy: 0.470500
# Epoch: 31, train_loss: 0.163463, val_loss: 2.587162, val_accuracy: 0.475400
# Epoch: 32, train_loss: 0.209436, val_loss: 2.578086, val_accuracy: 0.451600
# Epoch: 33, train_loss: 0.636989, val_loss: 2.776308, val_accuracy: 0.469800
# Epoch: 34, train_loss: 0.100814, val_loss: 2.571916, val_accuracy: 0.466800
# Epoch: 35, train_loss: 0.333267, val_loss: 2.305588, val_accuracy: 0.450500
# Epoch: 36, train_loss: 0.283478, val_loss: 2.853171, val_accuracy: 0.444300
# Epoch: 37, train_loss: 0.197825, val_loss: 2.889166, val_accuracy: 0.433000
# Epoch: 38, train_loss: 0.368741, val_loss: 3.575118, val_accuracy: 0.417400
# Epoch: 39, train_loss: 0.386188, val_loss: 4.092235, val_accuracy: 0.377700
# Epoch: 40, train_loss: 0.242904, val_loss: 3.150806, val_accuracy: 0.433600
# Epoch: 41, train_loss: 0.052562, val_loss: 2.856552, val_accuracy: 0.471600
# Epoch: 42, train_loss: 0.298463, val_loss: 2.963400, val_accuracy: 0.453500
# Epoch: 43, train_loss: 0.058652, val_loss: 2.957103, val_accuracy: 0.463600
# Epoch: 44, train_loss: 0.102975, val_loss: 2.755609, val_accuracy: 0.466400
# Epoch: 45, train_loss: 0.020469, val_loss: 2.974290, val_accuracy: 0.482100
# Epoch: 46, train_loss: 0.049733, val_loss: 2.729156, val_accuracy: 0.480600
# Epoch: 47, train_loss: 0.037270, val_loss: 2.883927, val_accuracy: 0.475700
# Epoch: 48, train_loss: 0.012618, val_loss: 3.045750, val_accuracy: 0.476100
# Epoch: 49, train_loss: 0.012274, val_loss: 2.929243, val_accuracy: 0.470500
# Epoch: 50, train_loss: 0.061002, val_loss: 2.922577, val_accuracy: 0.450900
# Epoch: 51, train_loss: 0.135214, val_loss: 2.774265, val_accuracy: 0.437700
# Epoch: 52, train_loss: 0.028746, val_loss: 2.766851, val_accuracy: 0.481500
# Epoch: 53, train_loss: 0.014262, val_loss: 2.503480, val_accuracy: 0.473800
# Epoch: 54, train_loss: 0.007240, val_loss: 2.981829, val_accuracy: 0.478800
# Epoch: 55, train_loss: 0.002665, val_loss: 3.028697, val_accuracy: 0.477300
# Epoch: 56, train_loss: 0.007201, val_loss: 3.055499, val_accuracy: 0.482100
# Epoch: 57, train_loss: 0.072440, val_loss: 3.452576, val_accuracy: 0.445900
# Epoch: 58, train_loss: 0.018539, val_loss: 3.061384, val_accuracy: 0.466500
# Epoch: 59, train_loss: 0.003816, val_loss: 3.053634, val_accuracy: 0.476900
# Epoch: 60, train_loss: 0.021207, val_loss: 2.909565, val_accuracy: 0.471300
# Epoch: 61, train_loss: 0.006035, val_loss: 3.094949, val_accuracy: 0.478500
# Epoch: 62, train_loss: 0.009053, val_loss: 3.042185, val_accuracy: 0.481200
# Epoch: 63, train_loss: 0.005921, val_loss: 3.155287, val_accuracy: 0.477500
# Epoch: 64, train_loss: 0.007823, val_loss: 3.074026, val_accuracy: 0.484100
# Epoch: 65, train_loss: 0.002595, val_loss: 3.084731, val_accuracy: 0.479600
# Epoch: 66, train_loss: 0.001536, val_loss: 3.072011, val_accuracy: 0.481000
# Epoch: 67, train_loss: 0.003563, val_loss: 3.092836, val_accuracy: 0.481100
# Epoch: 68, train_loss: 0.003415, val_loss: 3.058256, val_accuracy: 0.479400
# Epoch: 69, train_loss: 0.001480, val_loss: 3.105391, val_accuracy: 0.479600
# Epoch: 70, train_loss: 0.002479, val_loss: 3.082336, val_accuracy: 0.481100
# Epoch: 71, train_loss: 0.001564, val_loss: 3.123492, val_accuracy: 0.479900
# Epoch: 72, train_loss: 0.004750, val_loss: 3.096246, val_accuracy: 0.477600
# Epoch: 73, train_loss: 0.002960, val_loss: 3.123163, val_accuracy: 0.480400
# Epoch: 74, train_loss: 0.002336, val_loss: 3.099536, val_accuracy: 0.479100
# Epoch: 75, train_loss: 0.001174, val_loss: 3.129861, val_accuracy: 0.480300
# Epoch: 76, train_loss: 0.002167, val_loss: 3.131614, val_accuracy: 0.478100
# Epoch: 77, train_loss: 0.002050, val_loss: 3.120254, val_accuracy: 0.481200
# Epoch: 78, train_loss: 0.002711, val_loss: 3.121432, val_accuracy: 0.478800
# Epoch: 79, train_loss: 0.001693, val_loss: 3.152883, val_accuracy: 0.478800
# Epoch: 80, train_loss: 0.001530, val_loss: 3.141898, val_accuracy: 0.478900
# Epoch: 81, train_loss: 0.001646, val_loss: 3.140229, val_accuracy: 0.479800
# Epoch: 82, train_loss: 0.002176, val_loss: 3.165831, val_accuracy: 0.480000
# Epoch: 83, train_loss: 0.001228, val_loss: 3.159194, val_accuracy: 0.478900
# Epoch: 84, train_loss: 0.002162, val_loss: 3.158795, val_accuracy: 0.479300
# Epoch: 85, train_loss: 0.001628, val_loss: 3.198390, val_accuracy: 0.477400
# Epoch: 86, train_loss: 0.001167, val_loss: 3.167049, val_accuracy: 0.478700
# Epoch: 87, train_loss: 0.001617, val_loss: 3.183555, val_accuracy: 0.478500
# Epoch: 88, train_loss: 0.001581, val_loss: 3.182117, val_accuracy: 0.478000
# Epoch: 89, train_loss: 0.001289, val_loss: 3.200691, val_accuracy: 0.478100
# Epoch: 90, train_loss: 0.001992, val_loss: 3.194292, val_accuracy: 0.478600
# Epoch: 91, train_loss: 0.001122, val_loss: 3.214874, val_accuracy: 0.478500
# Epoch: 92, train_loss: 0.000705, val_loss: 3.206464, val_accuracy: 0.478600
# Epoch: 93, train_loss: 0.001379, val_loss: 3.203687, val_accuracy: 0.477500
# Epoch: 94, train_loss: 0.002889, val_loss: 3.216504, val_accuracy: 0.477800
# Epoch: 95, train_loss: 0.002188, val_loss: 3.220988, val_accuracy: 0.477800
# Epoch: 96, train_loss: 0.001325, val_loss: 3.229486, val_accuracy: 0.477700
# Epoch: 97, train_loss: 0.001238, val_loss: 3.221314, val_accuracy: 0.478400
# Epoch: 98, train_loss: 0.002600, val_loss: 3.247050, val_accuracy: 0.477300
# Epoch: 99, train_loss: 0.001160, val_loss: 3.241402, val_accuracy: 0.477600

# %% [markdown]
# # Some Notes

# %% [markdown]
# ## Torchvision's built-in datasets vs the provided base classes

# %% [markdown]
# https://pytorch.org/vision/main/datasets.html#built-in-datasets
#
# ![37.PNG](data:image/png;base64,...)

# %% [markdown]
# ![38.PNG](data:image/png;base64,...)

# %% [markdown]
# ## torch.utils.data.TensorDataset
#
# torch.utils.data.TensorDataset from a tensor.
# https://pytorch.org/docs/stable/data.html
#
# ![39.PNG](data:image/png;base64,...)

# %% [markdown]
# ## torch.utils.data.random_split
#
# https://pytorch.org/docs/stable/data.html
#
# Randomly split a dataset into non-overlapping new datasets of given lengths; for example, training dataset, validation dataset, and testing dataset.
#
# ![40.PNG](data:image/png;base64,...)
