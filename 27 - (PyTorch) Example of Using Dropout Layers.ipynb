# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms

# %% [markdown]
# # Set device variable

# %%
#device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#print(device)

# %% [markdown]
# # Prepare Dataset objects

# %%
data_path = './'

cifar10 = datasets.CIFAR10(
    data_path, train=True, download=False,
    transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4915, 0.4823, 0.4468),
                             (0.2470, 0.2435, 0.2616))
    ]))

cifar10_val = datasets.CIFAR10(
    data_path, train=False, download=False,
    transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4915, 0.4823, 0.4468),
                             (0.2470, 0.2435, 0.2616))
    ]))

n_out = 10

# %% [markdown]
# # Prepare Dataloader objects

# %%
#kwargs = {'num_workers': 1, 'pin_memory': True} if torch.cuda.is_available()else {}

train_loader = torch.utils.data.DataLoader(cifar10, batch_size=64, shuffle=True)#,  **kwargs)

val_loader = torch.utils.data.DataLoader(cifar10_val, batch_size=64,shuffle=False)#, **kwargs)

# %% [markdown]
# # Build a CNN Model with Dropout Layers

# %%
import torch.nn.functional as F

class NetDropout(nn.Module):
    def __init__(self, n_chans1=32):
        super().__init__()
        self.n_chans1 = n_chans1
        self.conv1 = nn.Conv2d(3, n_chans1, kernel_size=3, padding=1)
        self.conv1_dropout = nn.Dropout2d(p=0.4)
        self.conv2 = nn.Conv2d(n_chans1, n_chans1 // 2, kernel_size=3, padding=1)
        self.conv2_dropout = nn.Dropout2d(p=0.4)
        self.fc1 = nn.Linear(8 * 8 * n_chans1 // 2, 32)
        self.fc2 = nn.Linear(32, n_out)

    def forward(self, x):
        out = F.max_pool2d(torch.tanh(self.conv1(x)), 2)
        out = self.conv1_dropout(out)
        out = F.max_pool2d(torch.tanh(self.conv2(out)), 2)
        out = self.conv2_dropout(out)
        out = out.view(-1, 8 * 8 * self.n_chans1 // 2)
        out = torch.tanh(self.fc1(out))
        out = self.fc2(out)
        return out

model = NetDropout(n_chans1=16)

# model.to(device)

# %% [markdown]
# # Start Training

# %%
learning_rate = 1e-2

optimizer = optim.SGD(model.parameters(), lr=learning_rate)

loss_fn = nn.CrossEntropyLoss()

n_epochs = 100

for epoch in range(n_epochs):
    model.train(True)
    for imgs, labels in train_loader:
        #imgs, labels = imgs.to(device), labels.to(device)

        outputs = model(imgs)   # important:  nn.Conv2d expects a B × C × H × W shaped tensor as input
        train_loss = loss_fn(outputs, labels)

        optimizer.zero_grad()
        train_loss.backward()
        optimizer.step()

    model.eval()

    correct = 0
    total = 0
    with torch.no_grad():
        for imgs, labels in val_loader:
            #imgs, labels = imgs.to(device), labels.to(device)

            outputs = model(imgs)
            val_loss = loss_fn(outputs, labels)

            _, predicted = torch.max(outputs, dim=1)
            total += labels.shape[0]
            correct += int((predicted == labels).sum())
    print("Epoch: %d, train_loss: %f, val_loss: %f, val_accuracy: %f" % (epoch, float(train_loss), float(val_loss), (correct / total)))
# Out:
# Epoch: 0, train_loss: 2.059169, val_loss: 1.674422, val_accuracy: 0.328400
# Epoch: 1, train_loss: 1.948236, val_loss: 1.592086, val_accuracy: 0.376200
# Epoch: 2, train_loss: 2.134027, val_loss: 1.535188, val_accuracy: 0.399400
# Epoch: 3, train_loss: 1.441482, val_loss: 1.526527, val_accuracy: 0.425700
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 14
#      10 model.train(True)
#      11 for imgs, labels in train_loader:
#      12     #imgs, labels = imgs.to(device), labels.to(device)
# ---> 14     outputs = model(imgs)   # important:  nn.Conv2d expects a B × C × H × W shaped tensor as input
#      15     train_loss = loss_fn(outputs, labels)
#      17     optimizer.zero_grad()
#
# File D:\anaconda3\envs\ml_torch\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[5], line 15, in NetDropout.forward(self, x)
#      14 def forward(self, x):
# ---> 15     out = F.max_pool2d(torch.tanh(self.conv1(x)), 2)
#      16     out = self.conv1_dropout(out)
#      17     out = F.max_pool2d(torch.tanh(self.conv2(out)), 2)
#
# File D:\anaconda3\envs\ml_torch\lib\site-packages\torch\_jit_internal.py:484, in boolean_dispatch.<locals>.fn(*args, **kwargs)
#     482     return if_true(*args, **kwargs)
#     483 else:
# --> 484     return if_false(*args, **kwargs)
#
# File D:\anaconda3\envs\ml_torch\lib\site-packages\torch\nn\functional.py:782, in _max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode, return_indices)
#     780 if stride is None:
#     781     stride = torch.jit.annotate(List[int], [])
# --> 782 return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
#
# KeyboardInterrupt:
